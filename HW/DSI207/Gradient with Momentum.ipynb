# %%
import numpy as np

# %%
def objective(x):
    return x**2

def derivative(x):
    return 2*x

# %%
def gradient_w_momentum(n_iter,step_size, momentum, ini_solution):
    x_old = ini_solution
    momentum_old = 0
    
    for i in range(n_iter):
        #x_new = x_old - step_size*derivative(x_old) #original gradient
        
        x_new = x_old - (step_size*(-1)*derivative(x_old) + momentum*momentum_old) #gradient with momentum
        print(x_new, objective(x_new))
        
        x_old = x_new
        momentum_old = (step_size*(-1)*derivative(x_old) + momentum*momentum_old)

# %%
n_iter = 100
step_size = 0.3
momentum = 0.3
ini_solution = 3 

ini_solution
# Out:
# 3

# %%
result = gradient_w_momentum(n_iter, step_size, momentum, ini_solution)
# Out:
# 4.8 23.04
# 8.544 72.999936
# 15.46752 239.2441749504
# 28.0713216 787.9990963706266
# 50.963939328 2597.3231118280655
# 92.53075943424 8561.941441477195
# 168.0012887457792 28224.433020242675
# 305.0279160627855 93042.02957760572
# 553.8174468126199 306713.76439404907
# 1005.5268896601124 1011084.3258295398
# 1825.663556022976 3333047.4197904584
# 3314.7272894909365 10987417.003695931
# 6018.3142552501195 36220106.4749468
# 10927.0245519646 119399865.55923715
# 19839.42022556631 393602594.8866096
# 36021.02228423492 1297514046.4013486
# 65400.8046429368 4277265247.9435835
# 118743.58296087578 14100038494.386389
# 215594.26633001195 46480887674.37612
# 391439.15414520446 153224611397.91315
# 710708.1927836195 505106135289.7585
# 1290382.2470002305 1665086343373.3638
# 2342855.141224342 5488970212761.331
# 4253755.2151865205 18094433430726.52
# 7723240.379800279 59648441964177.555
# 14022537.48669505 196631557565767.9
# 25459722.590021566 648197474360854.4
# ...

# %%
result = gradient_w_momentum(n_iter, step_size, momentum, ini_solution)

#ได้ไม่เท่าจารย์
# Out:
# 4.8 23.04
# 8.544 72.999936
# 15.46752 239.2441749504
# 28.0713216 787.9990963706266
# 50.963939328 2597.3231118280655
# 92.53075943424 8561.941441477195
# 168.0012887457792 28224.433020242675
# 305.0279160627855 93042.02957760572
# 553.8174468126199 306713.76439404907
# 1005.5268896601124 1011084.3258295398
# 1825.663556022976 3333047.4197904584
# 3314.7272894909365 10987417.003695931
# 6018.3142552501195 36220106.4749468
# 10927.0245519646 119399865.55923715
# 19839.42022556631 393602594.8866096
# 36021.02228423492 1297514046.4013486
# 65400.8046429368 4277265247.9435835
# 118743.58296087578 14100038494.386389
# 215594.26633001195 46480887674.37612
# 391439.15414520446 153224611397.91315
# 710708.1927836195 505106135289.7585
# 1290382.2470002305 1665086343373.3638
# 2342855.141224342 5488970212761.331
# 4253755.2151865205 18094433430726.52
# 7723240.379800279 59648441964177.555
# 14022537.48669505 196631557565767.9
# 25459722.590021566 648197474360854.4
# ...
